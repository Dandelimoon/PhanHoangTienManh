# %% [markdown]
# Homework1-1

# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
x= int(input("Nhập n:"))
print(2*x)
# Out:
# 6

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a= float(input("Chiều rộng:"))
b= float(input("Chiều dài:"))
Dien_tich_san = a * b
Dien_tich_choi = (a/2) * (a/2) * 3.14 
Dien_tich_trong_hoa = Dien_tich_san - Dien_tich_choi
print("Diện tích trồng hoa:", f"{Dien_tich_trong_hoa:.2f}")
# Out:
# Diện tích trồng hoa: 4.93

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
b = ord(input("Nhập kí tự:"))
if b<=122 and b>=97:
    print(chr(b-32))
elif b<=90 and b>=65:
    print(chr(b+32))
else:
    print("Không phải là kí tự alphabet")
# Out:
# B

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet

# %%
a= ord(input("Nhập kí tự:"))
if (a>=65 and a<=90) or (a>=97 and a<=122):
    print("a là kí tự alphabet")
else:
    print("a không phải là kí tự alphabet")
# Out:
# a là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
a=ord(input("Nhập vào chữ in hoa:"))
if a>= 66 and a<= 90:
    print(chr(a+31))
elif a==65:
    print("Trường hợp đặc biệt")
else:
    print("Không phải là chữ in hoa")
# Out:
# a

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c= map(float, input("Nhập vào độ dài 3 cạnh:").split())
p=(a+b+c)/2
S=(p* (p-a)* (p-b)* (p-c))**(1/2)
if (a+b> c) or (a+c> b) or (b+c> a):
    print("Diện tích:", S) 
else:
    print("Không phải ba cạnh của tam giác")
# Out:
# Diện tích: 6.0

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a= input("Nhập chuỗi kí tự")
if len(a)>= 20:
    print(a[4], a[8])
else:
    print("Chưa đủ dài")
# Out:
# 5 9

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# Bậc 1: Từ 0 – 50kWh: 1.984 đồng/kWh
# Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%.

# %%
Ten= input("Nhập tên chủ hộ:")
D1= float(input("Số chỉ điện tháng trước:"))
D2= float(input("Số chỉ điện tháng này:"))
D= D2- D1
print("Tên chủ hộ:", Ten)
print("Số chỉ điện tháng trước:", D1, "kWh")
print("Số chỉ điện tháng này:", D2, "kWh")
if D>=0 and D<=50:
    print("Số tiền phải trả là:", f"{1984* 1.08* D:.2f}", "đồng")
elif D>=51 and D<=100:
    print("Số tiền phải trả là:", f"{2050* 1.08* D:.2f}", "đồng")
elif D>=101 and D<=200:
    print("Số tiền phải trả là:", f"{2380* 1.08* D:.2f}", "đồng")
elif D>=201 and D<=300:
    print("Số tiền phải trả là:", f"{2998* 1.08* D:.2f}", "đồng")
elif D>=301 and D<=400:
    print("Số tiền phải trả là:", f"{3350* 1.08* D:.2f}", "đồng")
else:
    print("Số tiền phải trả là:", f"{3460* 1.08* D:.2f}", "đồng")
# Out:
# Tên chủ hộ: Phan Hoàng Tiến Mạnh
# Số chỉ điện tháng trước: 100.0 kWh
# Số chỉ điện tháng này: 175.0 kWh
# Số tiền phải trả là: 166050.00 đồng
