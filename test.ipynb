# %%
print(3)
# Out:
# 3

# %%
BookA=int(input("tienA:"))
DonA=int(input('A:'))
BookB=int(input("tienB:"))
DonB=int(input('B:'))
Tong_Tien=(BookA * DonA) + (BookB* DonB)
print(Tong_Tien)
# Out:
# 130

# %%
a, b = int(input("tien1")), int(input("tien2"))
print(a+b)
# Out:
# 3

# %%
a=input("a:")
b=a.split()
print(b, sep("="))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 a=input("a:")
#       2 b=a.split()
# ----> 3 print(b, sep("="))
#
# NameError: name 'sep' is not defined
